# %% [markdown]
# # Archetypal analysis (AA) on ATAC
# This notebook tests AA part of ArchVelo package.

# %%
import numpy as np
import pandas as pd

# %%
from archetypal_regression.archetypes import *

# %%
import os

# %%
cwd = os.getcwd()+'/'

# %%
# indir should contain processed_data/adata_atac_raw.h5ad
# See processed_data/Readme.txt for details
indir = cwd

# %%
# make ourdir
outdir = cwd+'grouping_results/test/'
os.makedirs(outdir, exist_ok = True)

# %% [markdown]
# # AA test
# This notebook demonstrates AA component of ArchVelo.
# By default, ArchVelo splits any dataset into train and test sets in 3-to-1 proportion (create_archetypes method; see Create_archetypes.ipynb for further demonstration). This step is not necessary and to avoid that, apply_AA_no_test and create_archetypes_no_test methods can be used.

# %%
# test archetypal analysis

# requires indir, outdir
# k: number of components, default 8
# maxiter: maximal number of iterations for AA analysis, default 200

# Output in outdir directory:
# Z (peak_on_peaks), A_train (cell_train_on_peaks), A_test (cell_test_on_peaks)

apply_AA(indir, outdir, k = 8, maxiter = 2)
# Out:
# Fitting train data...
#
# Principal Convex Hull Analysis / Archetypal Analysis
# A 8 component model will be fitted
# To stop algorithm press control C
#
# -----------+------------+------------+-------------+------------+------------+------------+------------+
#  Iteration | Expl. var. | Cost func. | Delta SSEf. |        muC |    mualpha |        muS |  Time(s)
# -----------+------------+------------+-------------+------------+------------+------------+------------+
#          1 |     0.0012 | 5.9999e+07 | 3.1666e-01 | 1.9349e-01 | 6.1917e+00 | 2.3073e+00 |     5.0000
#
#          2 |     0.0082 | 5.9579e+07 | 7.0355e-03 | 2.9951e-01 | 3.8338e+01 | 1.4286e+01 |     5.0000
#
# -----------+------------+------------+-------------+------------+------------+------------+------------+
# -----------+------------+------------+-------------+------------+------------+------------+------------+
# ...
