# %%
import numpy as np
import pandas as pd

# %%
from archetypal_regression.archetypes import *

# %%
import os

# %%
cwd = os.getcwd()+'/'
os.makedirs(cwd+'grouping_results/test/', exist_ok = True)

# %%
adata_rna = sc.read_h5ad('processed_data/adata_rna.h5ad')

# %%
# from apply_AA import *
indir = cwd
outdir = cwd+'grouping_results/test/'
apply_AA_no_test(indir, outdir)
# Out:
# Applying AA...
#
# Principal Convex Hull Analysis / Archetypal Analysis
# A 8 component model will be fitted
# To stop algorithm press control C
#
# -----------+------------+------------+-------------+------------+------------+------------+------------+
#  Iteration | Expl. var. | Cost func. | Delta SSEf. |        muC |    mualpha |        muS |  Time(s)
# -----------+------------+------------+-------------+------------+------------+------------+------------+
#          1 |     0.0035 | 7.9662e+07 | 1.2921e-01 | 1.9349e-01 | 6.1917e+00 | 9.2292e+00 |     7.0000
#
#          2 |     0.0095 | 7.9184e+07 | 6.0316e-03 | 1.1980e+00 | 3.8338e+01 | 1.4286e+01 |     6.0000
#
#          3 |     0.0107 | 7.9085e+07 | 1.2560e-03 | 4.6363e-01 | 2.3738e+02 | 1.1057e+01 |     7.0000
#
#          4 |     0.0113 | 7.9038e+07 | 5.9252e-04 | 2.8706e+00 | 1.4698e+03 | 8.5578e+00 |     5.0000
#
#          5 |     0.0116 | 7.9016e+07 | 2.8023e-04 | 5.5545e-01 | 9.1004e+03 | 6.6234e+00 |     7.0000
#
# ...
